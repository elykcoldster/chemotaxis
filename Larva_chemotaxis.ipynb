# %%
#import pdb
from controller import Controller


def main():
    # TODO: create controller object and run
    controller = Controller()
    controller.run()

if __name__ == "__main__":
    #pdb.set_trace()
    main()
# Out:
# Creating Model singleton
# Time: 0.0, Enter command: a 0 0 5 5
# Added a larva: <larva.Larva object at 0x000001ADCDA362E8>
# Time: 0.0, Enter command: r 50
# Running 50 iteration(s)
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Time: 5.0, Enter command: v
# Time: 5.0, Enter command: r 40
# Running 40 iteration(s)
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: WEATHERVANE PSEUDO-STATE
# State: WV CRAWL FWD
# Updating a larva
# State: CAST START
# Updating a larva
# State: CAST TURN
# Updating a larva
# State: CAST TURN
# Updating a larva
# State: CAST TURN AFTER MIN ANGLE
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Time: 9.0, Enter command: v
# Time: 9.0, Enter command: r 100
# Running 100 iteration(s)
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: WEATHERVANE PSEUDO-STATE
# State: WV CRAWL FWD
# Updating a larva
# State: CAST START
# Updating a larva
# State: CAST TURN
# Updating a larva
# State: CAST TURN
# Updating a larva
# State: CAST TURN AFTER MIN ANGLE
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Updating a larva
# State: CRAWL FWD
# Time: 19.0, Enter command: v
