# %%
#import pdb
import sys
from controller import Controller


def main():
    controller = Controller()
    input_file = 'example_experiment_file.in'
    controller.run(input_file)

if __name__ == "__main__":
    #pdb.set_trace()
    main()
# Out:
# Added a larva: Location: [1 1]	Velocity: [ 0.70710678  0.70710678]
# Added Arena: Source Location: [ 0.  0.]	Source Strength: 10.0	Source Decay Rate: 5.0
# Running 5000 iteration(s)
# This is an instantaneous turn, Time = 26.80000000000011
# This is an instantaneous turn, Time = 34.900000000000226
# This is an instantaneous turn, Time = 61.90000000000061
# This is an instantaneous turn, Time = 71.20000000000023
# This is an instantaneous turn, Time = 89.09999999999921
# This is an instantaneous turn, Time = 89.69999999999918
# This is an instantaneous turn, Time = 91.49999999999908
# This is an instantaneous turn, Time = 105.59999999999827
# This is an instantaneous turn, Time = 105.89999999999826
# This is an instantaneous turn, Time = 107.29999999999818
# This is an instantaneous turn, Time = 117.89999999999758
# This is an instantaneous turn, Time = 129.7999999999969
# This is an instantaneous turn, Time = 156.5999999999954
# ...
