# %%
#import pdb
import sys
from controller import Controller
import random as rn


def main():
    controller = Controller()
    input_file = 'new_larva_new_arena.in'
    controller.run(input_file)

if __name__ == "__main__":
    #pdb.set_trace()
    rn.seed(1234)    
    main()
# Out:
# Added a larva: Location: [ 1.  1.]	Velocity: [-0.70710678  0.70710678]
# Added Arena: Source Location: [ 0.  0.]	Source Strength: 500.0	Source Bound: 25.0	Sigma Growth Rate: 0.01
# Running 5000 iteration(s)
